# %%
from icecube import icetray, dataio, phys_services
from icecube import dataclasses as dc
from I3Tray import I3Tray
import myGlobals as my
import numpy as np

# %%
class ExploreGCD(icetray.I3Module):
    def __init__(self, context):
        icetray.I3Module.__init__(self, context)
        self.AddOutBox('OutBox')

    def Configure(self):
        pass

    def Geometry(self, frame):
        self.geometry = frame['I3Geometry']
        self.PushFrame(frame)

    def Calibration(self, frame):
        self.calibration = frame['I3Calibration']
        self.PushFrame(frame)

    def DetectorStatus(self, frame):
        self.status = frame['I3DetectorStatus']
        
        self.om2index = {}
        self.tankpositions = []
        self.snowheight = []
        
        self.dom = self.status.dom_status
#         print('self.dom.keys() = {}'.format(self.dom.keys()))
        index = 0
        for number, station in self.geometry.stationgeo:
#             print('number = {}'.format(number))
#             print('station = {}'.format(station))
            for tank in station:
#                 print('tank = {}'.format(tank))
                omList = tank.omkey_list
                print('omList = {}'.format(omList))
                if not any([om in self.dom.keys() for om in omList]):
                    continue
                for om in omList:
                    self.om2index[om] = index
                self.tankpositions.append(tank.position)
                print('tank position = {}'.format(tank.position))
                self.snowheight.append(tank.snowheight)
                index += 1

        if len(self.tankpositions) < 5: # or some arbitrary low number
            raise ValueError("Not enough tanks found!")

#         self.hist = np.zeros([len(self.bins[i][1])-1 for i in self.bins])
#         self.snowheight = np.array(self.snowheight)
        self.PushFrame(frame)

    def Finish(self):
        return

# %%
ExploreGCD.DetectorStatus?

# %%
tray = I3Tray()
tray.Add('I3Reader', FileName='/data/sim/sim-new/downloads/GCD_31_08_11/GeoCalibDetectorStatus_IC79.55380_L2a.i3.gz')
tray.Add(ExploreGCD)
tray.Execute()
tray.Finish()
# Out:
# omList = [OMKey(2,61,0), OMKey(2,62,0)]
# tank position = I3Position(-140.36,-477.765,1945.24)
# omList = [OMKey(2,63,0), OMKey(2,64,0)]
# tank position = I3Position(-130.635,-476.575,1945.22)
# omList = [OMKey(3,61,0), OMKey(3,62,0)]
# tank position = I3Position(-27.72,-464.49,1945.41)
# omList = [OMKey(3,63,0), OMKey(3,64,0)]
# tank position = I3Position(-20.395,-458.975,1945.28)
# omList = [OMKey(4,61,0), OMKey(4,62,0)]
# tank position = I3Position(105.655,-438.705,1945.15)
# omList = [OMKey(4,63,0), OMKey(4,64,0)]
# tank position = I3Position(115.265,-436.865,1945.38)
# omList = [OMKey(5,61,0), OMKey(5,62,0)]
# tank position = I3Position(214.74,-432.41,1945.32)
# omList = [OMKey(5,63,0), OMKey(5,64,0)]
# tank position = I3Position(219.905,-424.685,1945.46)
# omList = [OMKey(6,61,0), OMKey(6,62,0)]
# tank position = I3Position(356.6,-398.13,1946.38)
# omList = [OMKey(6,63,0), OMKey(6,64,0)]
# tank position = I3Position(366.215,-398.38,1946.44)
# omList = [OMKey(8,61,0), OMKey(8,62,0)]
# tank position = I3Position(-231.225,-389.26,1944.97)
# omList = [OMKey(8,63,0), OMKey(8,64,0)]
# tank position = I3Position(-224.185,-382.945,1945.05)
# omList = [OMKey(9,61,0), OMKey(9,62,0)]
# tank position = I3Position(-85.195,-359.73,1944.9)
# omList = [OMKey(9,63,0), OMKey(9,64,0)]
# tank position = I3Position(-76.065,-362.44,1945)
# omList = [OMKey(10,61,0), OMKey(10,62,0)]
# tank position = I3Position(25.095,-342.47,1944.97)
# omList = [OMKey(10,63,0), OMKey(10,64,0)]
# tank position = I3Position(34.525,-339.745,1945.07)
# omList = [OMKey(11,61,0), OMKey(11,62,0)]
# tank position = I3Position(135.54,-353.385,1945.3)
# omList = [OMKey(11,63,0), OMKey(11,64,0)]
# tank position = I3Position(134.22,-343.48,1945.28)
# omList = [OMKey(12,61,0), OMKey(12,62,0)]
# tank position = I3Position(279.115,-300.46,1945.34)
# omList = [OMKey(12,63,0), OMKey(12,64,0)]
# tank position = I3Position(288.76,-301.51,1945.43)
# omList = [OMKey(13,61,0), OMKey(13,62,0)]
# tank position = I3Position(386.105,-290.32,1946.33)
# omList = [OMKey(13,63,0), OMKey(13,64,0)]
# tank position = I3Position(393.45,-283.77,1946.32)
# omList = [OMKey(15,61,0), OMKey(15,62,0)]
# tank position = I3Position(-265.695,-305,1945.25)
# omList = [OMKey(15,63,0), OMKey(15,64,0)]
# tank position = I3Position(-266.87,-314.8,1945.24)
# omList = [OMKey(16,61,0), OMKey(16,62,0)]
# tank position = I3Position(-182.25,-268.12,1945.18)
# omList = [OMKey(16,63,0), OMKey(16,64,0)]
# tank position = I3Position(-173.015,-263.84,1945.14)
# omList = [OMKey(17,61,0), OMKey(17,62,0)]
# tank position = I3Position(-40.355,-243.045,1944.57)
# omList = [OMKey(17,63,0), OMKey(17,64,0)]
# tank position = I3Position(-30.99,-246.07,1944.67)
# omList = [OMKey(18,61,0), OMKey(18,62,0)]
# tank position = I3Position(66.38,-227.17,1944.54)
# omList = [OMKey(18,63,0), OMKey(18,64,0)]
# tank position = I3Position(75.68,-223.735,1944.61)
# omList = [OMKey(19,61,0), OMKey(19,62,0)]
# tank position = I3Position(210.23,-185.1,1945.04)
# omList = [OMKey(19,63,0), OMKey(19,64,0)]
# tank position = I3Position(220.04,-186.245,1945.16)
# omList = [OMKey(20,61,0), OMKey(20,62,0)]
# tank position = I3Position(311.475,-228.47,1945.18)
# omList = [OMKey(20,63,0), OMKey(20,64,0)]
# tank position = I3Position(305.275,-220.86,1945.02)
# omList = [OMKey(21,61,0), OMKey(21,62,0)]
# tank position = I3Position(441.705,-212.675,1947.27)
# omList = [OMKey(21,63,0), OMKey(21,64,0)]
# tank position = I3Position(432.965,-207.025,1947.21)
# omList = [OMKey(23,61,0), OMKey(23,62,0)]
# tank position = I3Position(-388.975,-194.84,1945.21)
# omList = [OMKey(23,63,0), OMKey(23,64,0)]
# tank position = I3Position(-381.315,-188.66,1945.21)
# omList = [OMKey(24,61,0), OMKey(24,62,0)]
# tank position = I3Position(-225.47,-175.76,1945.15)
# omList = [OMKey(24,63,0), OMKey(24,64,0)]
# tank position = I3Position(-221.37,-184.48,1945.21)
# omList = [OMKey(25,61,0), OMKey(25,62,0)]
# tank position = I3Position(-102.535,-155.805,1945.22)
# omList = [OMKey(25,63,0), OMKey(25,64,0)]
# tank position = I3Position(-98.305,-164.685,1945.18)
# omList = [OMKey(26,61,0), OMKey(26,62,0)]
# tank position = I3Position(13.46,-129.355,1944.78)
# omList = [OMKey(26,63,0), OMKey(26,64,0)]
# tank position = I3Position(20.95,-135.915,1944.65)
# omList = [OMKey(27,61,0), OMKey(27,62,0)]
# tank position = I3Position(125.585,-106.195,1944.59)
# omList = [OMKey(27,63,0), OMKey(27,64,0)]
# tank position = I3Position(134.96,-108.71,1944.73)
# omList = [OMKey(28,61,0), OMKey(28,62,0)]
# tank position = I3Position(228.75,-95.84,1946.2)
# omList = [OMKey(28,63,0), OMKey(28,64,0)]
# tank position = I3Position(236.13,-89.84,1946.2)
# omList = [OMKey(29,61,0), OMKey(29,62,0)]
# tank position = I3Position(363.385,-115.685,1946.59)
# omList = [OMKey(29,63,0), OMKey(29,64,0)]
# tank position = I3Position(354.745,-110.06,1946.64)
# omList = [OMKey(30,61,0), OMKey(30,62,0)]
# tank position = I3Position(523.69,-67.345,1949.51)
# omList = [OMKey(30,63,0), OMKey(30,64,0)]
# tank position = I3Position(518.14,-76.075,1949.35)
# omList = [OMKey(32,61,0), OMKey(32,62,0)]
# tank position = I3Position(-452.62,-88.38,1945.17)
# omList = [OMKey(32,63,0), OMKey(32,64,0)]
# tank position = I3Position(-442.775,-88.615,1945.13)
# omList = [OMKey(33,61,0), OMKey(33,62,0)]
# tank position = I3Position(-304.56,-78.49,1945.16)
# omList = [OMKey(33,63,0), OMKey(33,64,0)]
# tank position = I3Position(-300.56,-87.37,1945.09)
# omList = [OMKey(34,61,0), OMKey(34,62,0)]
# tank position = I3Position(-181.055,-58.75,1945.37)
# omList = [OMKey(34,63,0), OMKey(34,64,0)]
# tank position = I3Position(-176.37,-68.215,1945.5)
# omList = [OMKey(35,61,0), OMKey(35,62,0)]
# tank position = I3Position(-86.4,-30.985,1945.96)
# omList = [OMKey(35,63,0), OMKey(35,64,0)]
# tank position = I3Position(-76.49,-29.475,1946.21)
# omList = [OMKey(36,61,0), OMKey(36,62,0)]
# tank position = I3Position(37.435,-57.36,1946.64)
# omList = [OMKey(36,63,0), OMKey(36,64,0)]
# tank position = I3Position(29.18,-52.805,1946.74)
# omList = [OMKey(37,61,0), OMKey(37,62,0)]
# tank position = I3Position(150.77,-31.065,1946.59)
# omList = [OMKey(37,63,0), OMKey(37,64,0)]
# tank position = I3Position(145.345,-22.655,1946.3)
# omList = [OMKey(38,61,0), OMKey(38,62,0)]
# tank position = I3Position(316.035,-3.805,1948.23)
# omList = [OMKey(38,63,0), OMKey(38,64,0)]
# tank position = I3Position(311.075,-12.415,1947.94)
# omList = [OMKey(39,61,0), OMKey(39,62,0)]
# tank position = I3Position(434.97,3.94,1949.28)
# omList = [OMKey(39,63,0), OMKey(39,64,0)]
# tank position = I3Position(429.565,-4.585,1949.28)
# omList = [OMKey(40,61,0), OMKey(40,62,0)]
# tank position = I3Position(530.605,20.97,1949.2)
# omList = [OMKey(40,63,0), OMKey(40,64,0)]
# tank position = I3Position(522.025,25.59,1949.18)
# omList = [OMKey(41,61,0), OMKey(41,62,0)]
# tank position = I3Position(-506.79,-0.845,1944.78)
# omList = [OMKey(41,63,0), OMKey(41,64,0)]
# tank position = I3Position(-502.225,-9.755,1944.95)
# omList = [OMKey(42,61,0), OMKey(42,62,0)]
# tank position = I3Position(-383.54,18.315,1945.37)
# omList = [OMKey(42,63,0), OMKey(42,64,0)]
# tank position = I3Position(-379.105,9.705,1945.3)
# omList = [OMKey(43,61,0), OMKey(43,62,0)]
# tank position = I3Position(-260.27,38.61,1945.16)
# omList = [OMKey(43,63,0), OMKey(43,64,0)]
# tank position = I3Position(-255.78,29.115,1945.17)
# omList = [OMKey(44,61,0), OMKey(44,62,0)]
# tank position = I3Position(-131.47,38.265,1945.5)
# omList = [OMKey(44,63,0), OMKey(44,64,0)]
# tank position = I3Position(-134.97,29.435,1945.61)
# omList = [OMKey(45,61,0), OMKey(45,62,0)]
# tank position = I3Position(-43.15,40.465,1945.93)
# omList = [OMKey(45,63,0), OMKey(45,64,0)]
# tank position = I3Position(-51.13,46.255,1945.9)
# omList = [OMKey(46,61,0), OMKey(46,62,0)]
# tank position = I3Position(71.35,66.825,1946.07)
# omList = [OMKey(46,63,0), OMKey(46,64,0)]
# tank position = I3Position(67.075,75.395,1946.05)
# omList = [OMKey(47,61,0), OMKey(47,62,0)]
# tank position = I3Position(172.68,114.555,1947.1)
# omList = [OMKey(47,63,0), OMKey(47,64,0)]
# tank position = I3Position(170.275,124.225,1947)
# omList = [OMKey(48,61,0), OMKey(48,62,0)]
# tank position = I3Position(365.45,151.485,1949.8)
# omList = [OMKey(48,63,0), OMKey(48,64,0)]
# tank position = I3Position(357.045,156.82,1949.82)
# omList = [OMKey(49,61,0), OMKey(49,62,0)]
# tank position = I3Position(495.22,136.94,1949.6)
# omList = [OMKey(49,63,0), OMKey(49,64,0)]
# tank position = I3Position(496.765,127.485,1949.59)
# omList = [OMKey(50,61,0), OMKey(50,62,0)]
# tank position = I3Position(604.155,147.51,1949.83)
# omList = [OMKey(50,63,0), OMKey(50,64,0)]
# tank position = I3Position(596.745,140.605,1949.86)
# omList = [OMKey(51,61,0), OMKey(51,62,0)]
# tank position = I3Position(-456.845,101.565,1945.18)
# omList = [OMKey(51,63,0), OMKey(51,64,0)]
# tank position = I3Position(-458.265,91.225,1945.12)
# omList = [OMKey(52,61,0), OMKey(52,62,0)]
# tank position = I3Position(-333.24,120.64,1945.59)
# omList = [OMKey(52,63,0), OMKey(52,64,0)]
# tank position = I3Position(-334.515,111.43,1945.63)
# omList = [OMKey(53,61,0), OMKey(53,62,0)]
# tank position = I3Position(-210.095,138.95,1945.56)
# omList = [OMKey(53,63,0), OMKey(53,64,0)]
# tank position = I3Position(-212.115,129.815,1945.63)
# omList = [OMKey(54,61,0), OMKey(54,62,0)]
# tank position = I3Position(-121.76,136.535,1945.45)
# omList = [OMKey(54,63,0), OMKey(54,64,0)]
# tank position = I3Position(-129.405,142.47,1945.43)
# omList = [OMKey(55,61,0), OMKey(55,62,0)]
# tank position = I3Position(21.235,155.665,1946.32)
# omList = [OMKey(55,63,0), OMKey(55,64,0)]
# tank position = I3Position(11.31,153.725,1946.36)
# omList = [OMKey(56,61,0), OMKey(56,62,0)]
# tank position = I3Position(133.065,174.71,1947.36)
# omList = [OMKey(56,63,0), OMKey(56,64,0)]
# tank position = I3Position(123.99,177.215,1947.31)
# omList = [OMKey(57,61,0), OMKey(57,62,0)]
# tank position = I3Position(248.745,194.56,1949.66)
# omList = [OMKey(57,63,0), OMKey(57,64,0)]
# tank position = I3Position(241.2,200.655,1949.57)
# omList = [OMKey(58,61,0), OMKey(58,62,0)]
# tank position = I3Position(400.485,220.525,1949.76)
# omList = [OMKey(58,63,0), OMKey(58,64,0)]
# tank position = I3Position(392.92,215.28,1949.75)
# omList = [OMKey(59,61,0), OMKey(59,62,0)]
# tank position = I3Position(525.245,241.565,1949.77)
# omList = [OMKey(59,63,0), OMKey(59,64,0)]
# tank position = I3Position(517.63,235.42,1949.56)
# omList = [OMKey(60,61,0), OMKey(60,62,0)]
# tank position = I3Position(-416.145,231.435,1945.58)
# omList = [OMKey(60,63,0), OMKey(60,64,0)]
# tank position = I3Position(-412.505,222.29,1945.59)
# omList = [OMKey(61,61,0), OMKey(61,62,0)]
# tank position = I3Position(-288.73,232.73,1945.89)
# omList = [OMKey(61,63,0), OMKey(61,64,0)]
# tank position = I3Position(-292.425,224,1945.87)
# omList = [OMKey(62,61,0), OMKey(62,62,0)]
# tank position = I3Position(-201.69,234.98,1945.96)
# omList = [OMKey(62,63,0), OMKey(62,64,0)]
# tank position = I3Position(-209.195,241.205,1945.99)
# omList = [OMKey(63,61,0), OMKey(63,62,0)]
# tank position = I3Position(-53.355,255.735,1946.52)
# omList = [OMKey(63,63,0), OMKey(63,64,0)]
# tank position = I3Position(-61.535,252.55,1946.45)
# omList = [OMKey(64,61,0), OMKey(64,62,0)]
# tank position = I3Position(64.765,272.45,1947.18)
# omList = [OMKey(64,63,0), OMKey(64,64,0)]
# tank position = I3Position(55.31,271.045,1947.32)
# omList = [OMKey(65,61,0), OMKey(65,62,0)]
# tank position = I3Position(153.605,302.965,1948.6)
# omList = [OMKey(65,63,0), OMKey(65,64,0)]
# tank position = I3Position(152.345,312.255,1948.48)
# omList = [OMKey(66,61,0), OMKey(66,62,0)]
# tank position = I3Position(319.945,316.945,1949.81)
# omList = [OMKey(66,63,0), OMKey(66,64,0)]
# tank position = I3Position(312.58,312.535,1949.71)
# omList = [OMKey(67,61,0), OMKey(67,62,0)]
# tank position = I3Position(440.305,333.415,1949.9)
# omList = [OMKey(67,63,0), OMKey(67,64,0)]
# tank position = I3Position(431.035,330.575,1949.86)
# omList = [OMKey(68,61,0), OMKey(68,62,0)]
# tank position = I3Position(-403.485,312.205,1945.64)
# omList = [OMKey(68,63,0), OMKey(68,64,0)]
# tank position = I3Position(-410.865,317.405,1945.57)
# omList = [OMKey(69,61,0), OMKey(69,62,0)]
# tank position = I3Position(-279.645,331.155,1946.09)
# omList = [OMKey(69,63,0), OMKey(69,64,0)]
# tank position = I3Position(-287.275,336.455,1946)
# omList = [OMKey(70,61,0), OMKey(70,62,0)]
# tank position = I3Position(-161.465,354.425,1946.18)
# omList = [OMKey(70,63,0), OMKey(70,64,0)]
# tank position = I3Position(-167.695,361.595,1946.22)
# omList = [OMKey(71,61,0), OMKey(71,62,0)]
# tank position = I3Position(-12.585,370.24,1946.98)
# omList = [OMKey(71,63,0), OMKey(71,64,0)]
# tank position = I3Position(-21.91,367.56,1947.06)
# omList = [OMKey(72,61,0), OMKey(72,62,0)]
# tank position = I3Position(123.515,400.915,1948.63)
# omList = [OMKey(72,63,0), OMKey(72,64,0)]
# tank position = I3Position(116.65,393.51,1948.63)
# omList = [OMKey(73,61,0), OMKey(73,62,0)]
# tank position = I3Position(207.945,413.015,1949.25)
# omList = [OMKey(73,63,0), OMKey(73,64,0)]
# tank position = I3Position(202.03,421.295,1949.24)
# omList = [OMKey(74,61,0), OMKey(74,62,0)]
# tank position = I3Position(369.32,431,1950.08)
# omList = [OMKey(74,63,0), OMKey(74,64,0)]
# tank position = I3Position(362.09,425.41,1949.98)
# omList = [OMKey(75,61,0), OMKey(75,62,0)]
# tank position = I3Position(-352.605,421.425,1946.01)
# omList = [OMKey(75,63,0), OMKey(75,64,0)]
# tank position = I3Position(-361.245,424.17,1946.03)
# omList = [OMKey(76,61,0), OMKey(76,62,0)]
# tank position = I3Position(-241.86,453.32,1946.28)
# omList = [OMKey(76,63,0), OMKey(76,64,0)]
# tank position = I3Position(-247.61,461.435,1946.19)
# omList = [OMKey(77,61,0), OMKey(77,62,0)]
# tank position = I3Position(-87.705,468.725,1946.85)
# omList = [OMKey(77,63,0), OMKey(77,64,0)]
# tank position = I3Position(-97.1,465.195,1946.98)
# omList = [OMKey(78,61,0), OMKey(78,62,0)]
# tank position = I3Position(2.11,494.62,1947.67)
# omList = [OMKey(78,63,0), OMKey(78,64,0)]
# tank position = I3Position(-2.02,503.595,1947.78)
